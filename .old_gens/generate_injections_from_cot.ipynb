# %%
import pickle
import torch

# %%
import os
import sys
import pickle
from typing import Any

PROJECT_ROOT = "/home/ADV_2526a/evyataroren/inter_2025"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

# Import the expected names from pipeline.interface
try:
    from pipeline.interface import DataPoint, Experiment  # type: ignore
except Exception as e:
    print("Failed to import from pipeline.interface:", e)
    raise

from pipeline.interface import DataPoint

# %%
dps = pickle.load(open("/home/ADV_2526a/evyataroren/inter_2025/artifacts/math500_whole_clean_no_activations_20260120_035034.pkl", "rb"))

# %%
for i, dp in enumerate(dps):
    print("dp #", i, ":", len(dp.upto_injection_tokens) )
# Out:
# dp # 0 : 1022
# dp # 1 : 1024
# dp # 2 : 1022
# dp # 3 : 1024
# dp # 4 : 1024
# dp # 5 : 1020
# dp # 6 : 1024
# dp # 7 : 1024
# dp # 8 : 1022
# dp # 9 : 1024
# dp # 10 : 1024
# dp # 11 : 1024
# dp # 12 : 1024
# dp # 13 : 1020
# dp # 14 : 1024
# dp # 15 : 1024
# dp # 16 : 1022
# dp # 17 : 1024
# dp # 18 : 1024
# dp # 19 : 1024
# dp # 20 : 1022
# dp # 21 : 1024
# dp # 22 : 1024
# dp # 23 : 1024
# dp # 24 : 1024
# dp # 25 : 1024
# dp # 26 : 1024
# dp # 27 : 1022
# dp # 28 : 1024
# dp # 29 : 1022
# dp # 30 : 1022
# dp # 31 : 1022
# dp # 32 : 1024
# dp # 33 : 1024
# dp # 34 : 1024
# dp # 35 : 1024
# dp # 36 : 1024
# dp # 37 : 1024
# dp # 38 : 1022
# dp # 39 : 1022
# dp # 40 : 1022
# dp # 41 : 1024
# dp # 42 : 1022
# dp # 43 : 1024
# dp # 44 : 1022
# dp # 45 : 1024
# dp # 46 : 1024
# dp # 47 : 1024
# dp # 48 : 1022
# dp # 49 : 1022
# dp # 50 : 1024
# dp # 51 : 1024
# dp # 52 : 1022
# dp # 53 : 1022
# dp # 54 : 1020
# dp # 55 : 1022
# dp # 56 : 1022
# dp # 57 : 1024
# dp # 58 : 1018
# ...

# %%
print("".join(dps[245].i))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print("".join(dps[245].injection_tokenized))
#
# NameError: name 'dps' is not defined
