# %%
import pandas as pd

unhelpful_thoughts_df = pd.read_parquet("../prompts/meta-cognitive-data/ai2_arc/unhelpful/test-00000-of-00001.parquet")
correct_thoughts_df = pd.read_parquet("../prompts/meta-cognitive-data/ai2_arc/unhelpful_correct/test-00000-of-00001.parquet")

# %%
# Display all columns (prevents truncation of columns themselves)
pd.set_option('display.max_columns', None)

# Display the full width of the content within each column (prevents text truncation with '...')
pd.set_option('display.max_colwidth', None)

# Optional: Adjust the display width for better formatting if using a terminal (less critical for Jupyter)
pd.set_option('display.width', None)

# %%
unhelpful_thoughts_df.head(1)
# Out:
#                 id  \
# 0  Mercury_7175875
#
#                                                                                                                                       question  \
# 0  An astronomer observes that a planet rotates faster after a meteorite impact. Which is the most likely effect of this increase in rotation?
#
#                                                                                                                                                                                                   choices  \
# 0  {'label': ['A', 'B', 'C', 'D'], 'text': ['Planetary density will decrease.', 'Planetary years will become longer.', 'Planetary days will become shorter.', 'Planetary gravity will become stronger.']}
#
#   answerKey  \
# 0         C
#
# ...

# %%
correct_thoughts_df.head(1)
# Out:
#                 id  \
# 0  Mercury_7175875
#
#                                                                                                                                       question  \
# 0  An astronomer observes that a planet rotates faster after a meteorite impact. Which is the most likely effect of this increase in rotation?
#
#                                                                                                                                                                                                   choices  \
# 0  {'label': ['A', 'B', 'C', 'D'], 'text': ['Planetary density will decrease.', 'Planetary years will become longer.', 'Planetary days will become shorter.', 'Planetary gravity will become stronger.']}
#
#   answerKey  \
# 0         C
#
# ...
